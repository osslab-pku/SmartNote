# %%
from config import init_env, settings

init_env("repo")
# Out:
# CUDA is available, using GPU NVIDIA GeForce RTX 3090 x4
# Invalid token: ***************************************************************************1QTNWUDJZZNUKNkqnL
# Invalid token: ***************************************************************************1QTNWUDJZZNUKNkqnL

# %%
from fetch_github import *
from calculate_stats import *

name_with_owner = "janhq/jan"
url = f"https://github.com/{name_with_owner}"
dest_dir = settings.CACHE_PATH / name_with_owner.replace("/", "_")
clone_repo(url, dest_dir)

# %%
# from github import Github
# import git

# gh = Github(settings.GITHUB_TOKEN)
# repo = git.Repo(dest_dir)

# _repo_stats = get_stats_ghapi(gh, name_with_owner)
# _releases = get_release_dates(gh, name_with_owner)
# _repo_stats, _releases

# %%
# df_releases = process_releases(repo, _releases)
# df_releases

# %%
# df_commits = get_commit_stats(repo, df_releases)
# del _repo_stats['name']
# df_commits = df_commits.assign(**_repo_stats)
# df_commits

# %%
# df_commits[['type', 'body']] = \
#     df_commits['message'].apply(lambda x: pd.Series(parse_commit_message(x), index=['type', 'body']))
# df_commits

# %%
import pandas as pd
import warnings

# This will suppress all PerformanceWarnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=pd.errors.PerformanceWarning)

# %%
from fetch_github import *
from calculate_stats import *
from github import Github
from typing import Literal
import git

def collect_features(name_with_owner: str, domain: Literal['Application', 'Library', 'System', 'Tool']) -> pd.DataFrame:
    url = f"https://github.com/{name_with_owner}"
    dest_dir = settings.CACHE_PATH / name_with_owner.replace("/", "_")
    clone_repo(url, dest_dir)

    gh = Github(settings.GITHUB_TOKEN)
    repo = git.Repo(dest_dir)

    _repo_stats = get_stats_ghapi(gh, name_with_owner)
    _releases = get_release_dates(gh, name_with_owner)
    df_releases = process_releases(repo, _releases)
    df_commits = get_commit_stats(repo, df_releases)

    del _repo_stats['name']
    _repo_stats['domain'] = domain
    df_commits = df_commits.assign(**_repo_stats)

    df_commits[['type', 'body']] = \
        df_commits['message'].apply(lambda x: pd.Series(parse_commit_message(x), index=['type', 'body']))

    df_commits['isMergeCommit'] = df_commits['message'].apply(is_merge_commit)
    df_commits.reset_index(inplace=True)
    df_commits.drop(columns=['files', 'message'], inplace=True)
    return df_commits

df_commits = collect_features('sindresorhus/ky', 'Library')
df_commits
# Out:
# Fetching releases: 100%|██████████| 73/73 [00:02<00:00, 32.39it/s]
# 2024-08-14 23:38:48.091 | WARNING  | calculate_stats:get_commit_stats:109 - Found 73 releases in sindresorhus_ky
# 2024-08-14 23:38:48.212 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.5.0...v1.6.0 (1/72): 7 commits
# v1.5.0...v1.6.0: 100%|██████████| 7/7 [00:00<00:00, 13.19it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:49.032 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.4.0...v1.5.0 (2/72): 8 commits
# v1.4.0...v1.5.0: 100%|██████████| 8/8 [00:00<00:00, 11.74it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:49.901 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.3.0...v1.4.0 (3/72): 8 commits
# v1.3.0...v1.4.0: 100%|██████████| 8/8 [00:00<00:00, 13.37it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:50.701 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.4...v1.3.0 (4/72): 5 commits
# v1.2.4...v1.3.0: 100%|██████████| 5/5 [00:00<00:00, 13.01it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:51.276 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.3...v1.2.4 (5/72): 7 commits
# v1.2.3...v1.2.4: 100%|██████████| 7/7 [00:00<00:00, 13.50it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:52.099 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.2...v1.2.3 (6/72): 3 commits
# v1.2.2...v1.2.3: 100%|██████████| 3/3 [00:00<00:00, 12.31it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:52.537 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.1...v1.2.2 (7/72): 3 commits
# v1.2.1...v1.2.2: 100%|██████████| 3/3 [00:00<00:00, 13.01it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:52.965 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.0...v1.2.1 (8/72): 3 commits
# v1.2.0...v1.2.1: 100%|██████████| 3/3 [00:00<00:00, 12.90it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:53.388 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.1.3...v1.2.0 (9/72): 6 commits
# v1.1.3...v1.2.0: 100%|██████████| 6/6 [00:00<00:00, 12.43it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:54.272 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.1.2...v1.1.3 (10/72): 3 commits
# v1.1.2...v1.1.3: 100%|██████████| 3/3 [00:00<00:00, 15.03it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:54.679 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.1.1...v1.1.2 (11/72): 3 commits
# v1.1.1...v1.1.2: 100%|██████████| 3/3 [00:00<00:00, 11.86it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:55.133 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.1.0...v1.1.1 (12/72): 3 commits
# v1.1.0...v1.1.1: 100%|██████████| 3/3 [00:00<00:00, 11.37it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:55.595 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.0.1...v1.1.0 (13/72): 5 commits
# v1.0.1...v1.1.0: 100%|██████████| 5/5 [00:00<00:00, 11.89it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:56.210 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.0.0...v1.0.1 (14/72): 3 commits
# v1.0.0...v1.0.1: 100%|██████████| 3/3 [00:00<00:00, 12.25it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:56.786 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.33.3...v1.0.0 (15/72): 5 commits
# v0.33.3...v1.0.0: 100%|██████████| 5/5 [00:00<00:00, 11.04it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:57.425 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.33.2...v0.33.3 (16/72): 5 commits
# v0.33.2...v0.33.3: 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:57.998 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.33.1...v0.33.2 (17/72): 4 commits
# v0.33.1...v0.33.2: 100%|██████████| 4/4 [00:00<00:00, 12.71it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:58.511 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.33.0...v0.33.1 (18/72): 3 commits
# v0.33.0...v0.33.1: 100%|██████████| 3/3 [00:00<00:00, 11.90it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:59.090 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.32.2...v0.33.0 (19/72): 6 commits
# v0.32.2...v0.33.0: 100%|██████████| 6/6 [00:00<00:00, 11.20it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:38:59.826 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.32.1...v0.32.2 (20/72): 3 commits
# v0.32.1...v0.32.2: 100%|██████████| 3/3 [00:00<00:00, 12.29it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:00.268 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.32.0...v0.32.1 (21/72): 4 commits
# v0.32.0...v0.32.1: 100%|██████████| 4/4 [00:00<00:00, 11.90it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:00.804 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.31.4...v0.32.0 (22/72): 5 commits
# v0.31.4...v0.32.0: 100%|██████████| 5/5 [00:00<00:00, 11.29it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:01.451 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.31.3...v0.31.4 (23/72): 4 commits
# v0.31.3...v0.31.4: 100%|██████████| 4/4 [00:00<00:00, 11.87it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:02.108 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.31.2...v0.31.3 (24/72): 3 commits
# v0.31.2...v0.31.3: 100%|██████████| 3/3 [00:00<00:00, 12.13it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:02.557 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.31.1...v0.31.2 (25/72): 5 commits
# v0.31.1...v0.31.2: 100%|██████████| 5/5 [00:00<00:00, 12.87it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:03.139 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.31.0...v0.31.1 (26/72): 3 commits
# v0.31.0...v0.31.1: 100%|██████████| 3/3 [00:00<00:00, 13.13it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:03.551 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.30.0...v0.31.0 (27/72): 6 commits
# v0.30.0...v0.31.0: 100%|██████████| 6/6 [00:00<00:00, 12.98it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:04.199 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.29.0...v0.30.0 (28/72): 4 commits
# v0.29.0...v0.30.0: 100%|██████████| 4/4 [00:00<00:00, 12.12it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:04.829 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.7...v0.29.0 (29/72): 5 commits
# v0.28.7...v0.29.0: 100%|██████████| 5/5 [00:00<00:00, 12.71it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:05.409 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.6...v0.28.7 (30/72): 5 commits
# v0.28.6...v0.28.7: 100%|██████████| 5/5 [00:00<00:00, 12.21it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:06.006 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.5...v0.28.6 (31/72): 9 commits
# v0.28.5...v0.28.6: 100%|██████████| 9/9 [00:00<00:00, 12.65it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:06.907 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.4...v0.28.5 (32/72): 3 commits
# v0.28.4...v0.28.5: 100%|██████████| 3/3 [00:00<00:00, 12.47it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:07.332 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.3...v0.28.4 (33/72): 3 commits
# v0.28.3...v0.28.4: 100%|██████████| 3/3 [00:00<00:00, 13.00it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:07.895 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.2...v0.28.3 (34/72): 4 commits
# v0.28.2...v0.28.3: 100%|██████████| 4/4 [00:00<00:00, 13.20it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:08.382 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.1...v0.28.2 (35/72): 4 commits
# v0.28.1...v0.28.2: 100%|██████████| 4/4 [00:00<00:00, 13.67it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:08.867 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.28.0...v0.28.1 (36/72): 3 commits
# v0.28.0...v0.28.1: 100%|██████████| 3/3 [00:00<00:00, 12.73it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:09.286 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.27.0...v0.28.0 (37/72): 8 commits
# v0.27.0...v0.28.0: 100%|██████████| 8/8 [00:00<00:00, 10.71it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:10.230 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.26.0...v0.27.0 (38/72): 10 commits
# v0.26.0...v0.27.0: 100%|██████████| 10/10 [00:00<00:00, 12.15it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:11.243 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.25.1...v0.26.0 (39/72): 12 commits
# v0.25.1...v0.26.0: 100%|██████████| 12/12 [00:01<00:00, 11.90it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:12.650 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.25.0...v0.25.1 (40/72): 5 commits
# v0.25.0...v0.25.1: 100%|██████████| 5/5 [00:00<00:00, 12.70it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:13.237 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.24.0...v0.25.0 (41/72): 8 commits
# v0.24.0...v0.25.0: 100%|██████████| 8/8 [00:00<00:00, 13.54it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:14.023 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.23.0...v0.24.0 (42/72): 4 commits
# v0.23.0...v0.24.0: 100%|██████████| 4/4 [00:00<00:00, 12.65it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:14.527 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.22.0...v0.23.0 (43/72): 4 commits
# v0.22.0...v0.23.0: 100%|██████████| 4/4 [00:00<00:00, 12.12it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:15.083 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.21.0...v0.22.0 (44/72): 5 commits
# v0.21.0...v0.22.0: 100%|██████████| 5/5 [00:00<00:00, 12.22it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:15.881 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.20.0...v0.21.0 (45/72): 3 commits
# v0.20.0...v0.21.0: 100%|██████████| 3/3 [00:00<00:00, 12.18it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:16.324 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.19.1...v0.20.0 (46/72): 4 commits
# v0.19.1...v0.20.0: 100%|██████████| 4/4 [00:00<00:00, 12.68it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:16.847 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.19.0...v0.19.1 (47/72): 4 commits
# v0.19.0...v0.19.1: 100%|██████████| 4/4 [00:00<00:00, 11.78it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:17.371 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.18.0...v0.19.0 (48/72): 4 commits
# v0.18.0...v0.19.0: 100%|██████████| 4/4 [00:00<00:00, 11.21it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:17.923 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.17.0...v0.18.0 (49/72): 5 commits
# v0.17.0...v0.18.0: 100%|██████████| 5/5 [00:00<00:00, 12.08it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:18.538 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.16.2...v0.17.0 (50/72): 6 commits
# v0.16.2...v0.17.0: 100%|██████████| 6/6 [00:00<00:00, 11.27it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:19.273 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.16.1...v0.16.2 (51/72): 5 commits
# v0.16.1...v0.16.2: 100%|██████████| 5/5 [00:00<00:00, 11.73it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:20.073 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.16.0...v0.16.1 (52/72): 5 commits
# v0.16.0...v0.16.1: 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:20.626 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.15.0...v0.16.0 (53/72): 12 commits
# v0.15.0...v0.16.0: 100%|██████████| 12/12 [00:00<00:00, 12.06it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:21.810 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.14.0...v0.15.0 (54/72): 5 commits
# v0.14.0...v0.15.0: 100%|██████████| 5/5 [00:00<00:00, 13.25it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:22.365 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.13.0...v0.14.0 (55/72): 7 commits
# v0.13.0...v0.14.0: 100%|██████████| 7/7 [00:00<00:00, 12.47it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:23.113 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.12.0...v0.13.0 (56/72): 7 commits
# v0.12.0...v0.13.0: 100%|██████████| 7/7 [00:00<00:00, 12.84it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:23.841 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.11.2...v0.12.0 (57/72): 6 commits
# v0.11.2...v0.12.0: 100%|██████████| 6/6 [00:00<00:00, 13.06it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:24.675 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.11.1...v0.11.2 (58/72): 6 commits
# v0.11.1...v0.11.2: 100%|██████████| 6/6 [00:00<00:00, 13.01it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:25.326 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.11.0...v0.11.1 (59/72): 4 commits
# v0.11.0...v0.11.1: 100%|██████████| 4/4 [00:00<00:00, 13.33it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:25.819 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.10.0...v0.11.0 (60/72): 11 commits
# v0.10.0...v0.11.0: 100%|██████████| 11/11 [00:00<00:00, 12.76it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:26.876 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.9.1...v0.10.0 (61/72): 6 commits
# v0.9.1...v0.10.0: 100%|██████████| 6/6 [00:00<00:00, 13.09it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:27.529 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.9.0...v0.9.1 (62/72): 10 commits
# v0.9.0...v0.9.1: 100%|██████████| 10/10 [00:00<00:00, 14.08it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:28.442 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.8.0...v0.9.0 (63/72): 8 commits
# v0.8.0...v0.9.0: 100%|██████████| 8/8 [00:00<00:00, 11.46it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:29.331 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.7.1...v0.8.0 (64/72): 4 commits
# v0.7.1...v0.8.0: 100%|██████████| 4/4 [00:00<00:00, 11.37it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:30.033 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.7.0...v0.7.1 (65/72): 6 commits
# v0.7.0...v0.7.1: 100%|██████████| 6/6 [00:00<00:00, 13.11it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:30.717 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.6.0...v0.7.0 (66/72): 6 commits
# v0.6.0...v0.7.0: 100%|██████████| 6/6 [00:00<00:00, 12.29it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:31.430 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.5.2...v0.6.0 (67/72): 11 commits
# v0.5.2...v0.6.0: 100%|██████████| 11/11 [00:00<00:00, 13.23it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:32.451 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.5.1...v0.5.2 (68/72): 5 commits
# v0.5.1...v0.5.2: 100%|██████████| 5/5 [00:00<00:00, 12.00it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:33.066 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.5.0...v0.5.1 (69/72): 4 commits
# v0.5.0...v0.5.1: 100%|██████████| 4/4 [00:00<00:00, 12.25it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:33.587 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.4.1...v0.5.0 (70/72): 12 commits
# v0.4.1...v0.5.0: 100%|██████████| 12/12 [00:00<00:00, 13.03it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:34.865 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.4.0...v0.4.1 (71/72): 5 commits
# v0.4.0...v0.4.1: 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:39:35.439 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.3.0...v0.4.0 (72/72): 7 commits
# v0.3.0...v0.4.0: 100%|██████████| 7/7 [00:00<00:00, 13.35it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:3641: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]
# /tmp/ipykernel_188202/2415618806.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits['isMergeCommit'] = df_commits['message'].apply(is_merge_commit)
# /tmp/ipykernel_188202/2415618806.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits.reset_index(inplace=True)
#                                           sha    nameWithOwner  \
# 0    a7204c4672d10a144b12ef169c8d38e17db81931  sindresorhus_ky
# 1    8531b050918d54066abb9f11b0193b893e77718f  sindresorhus_ky
# 2    fbe0ec68b052a9df6221a3531553783860925289  sindresorhus_ky
# 3    9728f4bd47a00f7aabb1be433c8879ec6e1e584c  sindresorhus_ky
# 4    2376cf2bdfc97cee92df220a51e69dd3ef700eef  sindresorhus_ky
# ..                                        ...              ...
# 392  66fb6c37921244ec7ca94068749effa4aa69c5cb  sindresorhus_ky
# 393  91de80f0b9b4db9760f6f247f5f5d8f1d1ab256a  sindresorhus_ky
# 394  81bbf7b6f6eed796b2f9c711ee96f5f298367818  sindresorhus_ky
# 395  6a32b54b61b2d6209ff048fa5b7b598c80032b7e  sindresorhus_ky
# 396  52bc75aaddc02b072b5d17d270e96dbd841d0810  sindresorhus_ky
#
#           authorName                                   authorEmail  \
# 0      Sindre Sorhus                        sindresorhus@gmail.com
# 1      Seth Holladay                          me@seth-holladay.com
# 2      Seth Holladay                          me@seth-holladay.com
# 3      Sindre Sorhus                        sindresorhus@gmail.com
# 4    Christian Owusu  36159205+crisshaker@users.noreply.github.com
# ..               ...                                           ...
# 392    Seth Holladay                          me@seth-holladay.com
# 393  Thijs Triemstra                                info@collab.nl
# 394    Sindre Sorhus                        sindresorhus@gmail.com
# 395    Sindre Sorhus                        sindresorhus@gmail.com
# 396    Sindre Sorhus                        sindresorhus@gmail.com
#
#                           date  nFiles  addLines  delLines  lang1CEnterprise  \
# 0    2024-08-13 11:19:59+02:00       1         1         1                 0
# 1    2024-08-12 19:27:37-04:00       4        74         3                 0
# 2    2024-08-10 17:29:40-04:00       1         0         5                 0
# 3    2024-08-08 15:06:10+02:00       1         0        14                 0
# 4    2024-07-31 18:04:40-04:00       2        21         7                 0
# ..                         ...     ...       ...       ...               ...
# 392  2018-09-30 01:30:24+07:00       4        81         1                 0
# 393  2018-09-30 01:28:55+07:00       1         1         1                 0
# 394  2018-09-17 19:20:09+07:00       1         1         1                 0
# 395  2018-09-17 13:14:28+07:00       6       163       148                 0
# 396  2018-09-17 12:12:48+07:00       1         1         1                 0
#
#      langAbap  ...  commits  contributors  issues  prs  stars  comments  \
# 0           0  ...      341            99     331  228  12834      2343
# 1           0  ...      341            99     331  228  12834      2343
# 2           0  ...      341            99     331  228  12834      2343
# 3           0  ...      341            99     331  228  12834      2343
# 4           0  ...      341            99     331  228  12834      2343
# ..        ...  ...      ...           ...     ...  ...    ...       ...
# 392         0  ...      341            99     331  228  12834      2343
# 393         0  ...      341            99     331  228  12834      2343
# 394         0  ...      341            99     331  228  12834      2343
# 395         0  ...      341            99     331  228  12834      2343
# 396         0  ...      341            99     331  228  12834      2343
#
#       domain  type                                               body  \
# 0    Library  None                                              1.6.0
# 1    Library  None  Add support for the `RateLimit-Reset` header (...
# 2    Library  None  Remove unnecessary setting of `credentials` op...
# 3    Library  None                                        Meta tweaks
# 4    Library  None  Fix signal handling for Request objects (#613)...
# ..       ...   ...                                                ...
# 392  Library  None           Add `prefixUrl` option (#11)\n\nFixes #1
# 393  Library  None                        Fix usage example URL (#38)
# 394  Library  None  Change `retry` option default to what's actual...
# 395  Library  None                    Split tests into multiple files
# 396  Library  None                                              0.3.0
#
#      isMergeCommit
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 392          False
# 393          False
# 394          False
# 395          False
# 396          False
#
# [397 rows x 457 columns]

# %%
# df_commits

# %%
df_commits_gt = pd.read_parquet(settings.DATASETS_PATH / 'dataset_cls.parquet')

# check column diffs
set(df_commits_gt.columns) - set(df_commits.columns), set(df_commits.columns) - set(df_commits_gt.columns)
# Out:
# ({'isInRN'}, set())

# %%
import pandas as pd
import warnings

# This will suppress all PerformanceWarnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=pd.errors.PerformanceWarning)

# %%
import xgboost as xgb
from sklearn.metrics import classification_report

clf = xgb.XGBClassifier(
        objective="multi:softmax",
        tree_method="hist", 
        enable_categorical=True, 
        device="cuda",
        eval_metric="mlogloss",
        random_state=settings.SEED,
        early_stopping_rounds=10,
    )

clf.load_model('../models/cls_gte_xgb/cls_gte_xgb_split.json')
clf
# Out:
# XGBClassifier(base_score='5E-1', booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=10,
#               enable_categorical=True, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softmax', ...)

# %%
flt = xgb.XGBClassifier(
    objective="binary:logistic",
    tree_method="hist", 
    enable_categorical=True, 
    device="cuda",
    eval_metric="logloss",
    early_stopping_rounds=10,
    random_state=settings.SEED,
)

flt.load_model('../models/flt_gte_xgb/flt_gte_xgb_split.json')
flt
# Out:
# XGBClassifier(base_score='2.1564357E-1', booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=10,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, random_state=19260817, ...)

# %%
import torch
import torch.nn.functional as F
from transformers import AutoModel, AutoTokenizer

# why gte?
# 1. top 20 on mteb classification https://huggingface.co/BAAI/bge-base-en-v1.5
# 2. very small model (137M parameters) for fast training and inference
model_path = 'Alibaba-NLP/gte-base-en-v1.5'
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModel.from_pretrained(model_path, trust_remote_code=True).to(settings.TORCH_DEVICE)
model
# Out:
# NewModel(
#   (embeddings): NewEmbeddings(
#     (word_embeddings): Embedding(30528, 768, padding_idx=0)
#     (rotary_emb): NTKScalingRotaryEmbedding()
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): NewEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x NewLayer(
#         (attention): NewSdpaAttention(
#           (qkv_proj): Linear(in_features=768, out_features=2304, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (o_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (mlp): NewGatedMLP(
#           (up_gate_proj): Linear(in_features=768, out_features=6144, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=768, bias=True)
#           (act_fn): GELUActivation()
#           (hidden_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (attn_ln): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (mlp_ln): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (hidden_dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
# )

# %%
settings.BATCH_SIZE = 32

with torch.no_grad():
    _df_embs = []
    # chunk df['body']
    for _texts in tqdm(np.array_split(
        df_commits['body'], len(df_commits) // settings.BATCH_SIZE)):
        _texts = _texts.tolist()
        batch_dict = tokenizer(
            _texts, max_length=8192, padding=True, truncation=True, return_tensors='pt'
        ).to(settings.TORCH_DEVICE)
        outputs = model(**batch_dict)
        embeddings = outputs.last_hidden_state[:, 0].cpu().detach().numpy()
        _df_embs.append(embeddings)

# concatenate all embeddings
df_embs = pd.concat([pd.DataFrame(_embs) for _embs in _df_embs], ignore_index=True)
# name the columns: emb0, emb1, ..., emb767
df_embs.columns = [f'emb{i}' for i in range(df_embs.shape[1])]
# Out:
# 100%|██████████| 12/12 [00:01<00:00,  8.88it/s]

# %%
from sklearn.preprocessing import LabelEncoder

df_ds = pd.concat([df_commits, df_embs], axis=1)\
    .drop(columns=['nameWithOwner', 'sha', 'authorName', 'authorEmail', 'date', 'releaseTag', 'body'])

_encode_releaseType = LabelEncoder()
_encode_releaseType.fit(settings.categories.release_types)
df_ds['releaseType'] = pd.Series(_encode_releaseType.transform(df_ds['releaseType'])).astype('category')

_encoder_domain = LabelEncoder()
_encoder_domain.fit(settings.categories.project_domains)
df_ds['domain'] = pd.Series(_encoder_domain.transform(df_ds['domain'])).astype('category')

_encoder_type = LabelEncoder()
_encoder_type.fit(settings.categories.conventional_commits)

X, y = df_ds.drop(columns=['type']), df_ds['type']
X
# Out:
#      nFiles  addLines  delLines  lang1CEnterprise  langAbap  langAgsScript  \
# 0         1         1         1                 0         0              0
# 1         4        74         3                 0         0              0
# 2         1         0         5                 0         0              0
# 3         1         0        14                 0         0              0
# 4         2        21         7                 0         0              0
# ..      ...       ...       ...               ...       ...            ...
# 392       4        81         1                 0         0              0
# 393       1         1         1                 0         0              0
# 394       1         1         1                 0         0              0
# 395       6       163       148                 0         0              0
# 396       1         1         1                 0         0              0
#
#      langAmpl  langAntlr  langApiBlueprint  langApl  ...    emb758    emb759  \
# 0           0          0                 0        0  ... -0.583360  0.143082
# 1           0          0                 0        0  ... -0.522438  0.457055
# 2           0          0                 0        0  ... -0.521769  0.640792
# 3           0          0                 0        0  ...  0.126201 -0.436450
# 4           0          0                 0        0  ...  0.097018  0.267044
# ..        ...        ...               ...      ...  ...       ...       ...
# 392         0          0                 0        0  ...  0.708609  0.116949
# 393         0          0                 0        0  ... -0.580172 -0.082393
# 394         0          0                 0        0  ... -0.699018  0.441958
# 395         0          0                 0        0  ... -0.545646 -0.069085
# 396         0          0                 0        0  ... -0.359342  0.271740
#
#        emb760    emb761    emb762    emb763    emb764    emb765    emb766  \
# 0   -1.154064 -0.959733 -0.765771 -0.044890 -0.691532 -0.369768 -0.168901
# 1   -0.611719 -0.627040  0.341583  0.546461 -0.418430  0.535241 -0.378521
# 2    0.350593 -1.257630  0.516390  0.482716  0.189354  0.777511  0.206443
# 3    0.051622 -0.211255  0.074482  0.049015  0.316855 -0.058528 -0.413718
# 4   -0.363260 -0.725803 -0.144390 -0.075176 -0.092133  0.112683 -0.279193
# ..        ...       ...       ...       ...       ...       ...       ...
# 392  0.181189 -0.392052  0.948211  0.785493  0.213842 -0.797044 -0.217458
# 393  0.254036 -0.087053  0.220210  0.589585  0.079311 -0.242603 -0.300730
# 394 -0.750832 -0.924948 -0.236086 -0.206215 -0.929462 -0.030419  0.330442
# 395 -0.030802 -0.175431 -0.720341 -0.738620  0.316433 -0.219625  0.326398
# 396 -0.977119 -0.948595 -0.201071 -0.643732 -1.144512 -0.498198 -0.484436
#
#        emb767
# 0   -0.132958
# 1    0.233670
# 2    0.347536
# 3    1.000672
# 4    0.149215
# ..        ...
# 392 -0.094795
# 393 -0.231640
# 394  0.711296
# 395 -0.142135
# 396 -0.362806
#
# [397 rows x 1217 columns]

# %%
y_pred = clf.predict(X)
df_commits['predictedType'] = _encoder_type.inverse_transform(y_pred)
df_commits
# Out:
# /tmp/ipykernel_188202/2563490475.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits['predictedType'] = _encoder_type.inverse_transform(y_pred)
#                                           sha    nameWithOwner  \
# 0    a7204c4672d10a144b12ef169c8d38e17db81931  sindresorhus_ky
# 1    8531b050918d54066abb9f11b0193b893e77718f  sindresorhus_ky
# 2    fbe0ec68b052a9df6221a3531553783860925289  sindresorhus_ky
# 3    9728f4bd47a00f7aabb1be433c8879ec6e1e584c  sindresorhus_ky
# 4    2376cf2bdfc97cee92df220a51e69dd3ef700eef  sindresorhus_ky
# ..                                        ...              ...
# 392  66fb6c37921244ec7ca94068749effa4aa69c5cb  sindresorhus_ky
# 393  91de80f0b9b4db9760f6f247f5f5d8f1d1ab256a  sindresorhus_ky
# 394  81bbf7b6f6eed796b2f9c711ee96f5f298367818  sindresorhus_ky
# 395  6a32b54b61b2d6209ff048fa5b7b598c80032b7e  sindresorhus_ky
# 396  52bc75aaddc02b072b5d17d270e96dbd841d0810  sindresorhus_ky
#
#           authorName                                   authorEmail  \
# 0      Sindre Sorhus                        sindresorhus@gmail.com
# 1      Seth Holladay                          me@seth-holladay.com
# 2      Seth Holladay                          me@seth-holladay.com
# 3      Sindre Sorhus                        sindresorhus@gmail.com
# 4    Christian Owusu  36159205+crisshaker@users.noreply.github.com
# ..               ...                                           ...
# 392    Seth Holladay                          me@seth-holladay.com
# 393  Thijs Triemstra                                info@collab.nl
# 394    Sindre Sorhus                        sindresorhus@gmail.com
# 395    Sindre Sorhus                        sindresorhus@gmail.com
# 396    Sindre Sorhus                        sindresorhus@gmail.com
#
#                           date  nFiles  addLines  delLines  lang1CEnterprise  \
# 0    2024-08-13 11:19:59+02:00       1         1         1                 0
# 1    2024-08-12 19:27:37-04:00       4        74         3                 0
# 2    2024-08-10 17:29:40-04:00       1         0         5                 0
# 3    2024-08-08 15:06:10+02:00       1         0        14                 0
# 4    2024-07-31 18:04:40-04:00       2        21         7                 0
# ..                         ...     ...       ...       ...               ...
# 392  2018-09-30 01:30:24+07:00       4        81         1                 0
# 393  2018-09-30 01:28:55+07:00       1         1         1                 0
# 394  2018-09-17 19:20:09+07:00       1         1         1                 0
# 395  2018-09-17 13:14:28+07:00       6       163       148                 0
# 396  2018-09-17 12:12:48+07:00       1         1         1                 0
#
#      langAbap  ...  contributors  issues  prs  stars  comments   domain  type  \
# 0           0  ...            99     331  228  12834      2343  Library  None
# 1           0  ...            99     331  228  12834      2343  Library  None
# 2           0  ...            99     331  228  12834      2343  Library  None
# 3           0  ...            99     331  228  12834      2343  Library  None
# 4           0  ...            99     331  228  12834      2343  Library  None
# ..        ...  ...           ...     ...  ...    ...       ...      ...   ...
# 392         0  ...            99     331  228  12834      2343  Library  None
# 393         0  ...            99     331  228  12834      2343  Library  None
# 394         0  ...            99     331  228  12834      2343  Library  None
# 395         0  ...            99     331  228  12834      2343  Library  None
# 396         0  ...            99     331  228  12834      2343  Library  None
#
#                                                   body  isMergeCommit  \
# 0                                                1.6.0          False
# 1    Add support for the `RateLimit-Reset` header (...          False
# 2    Remove unnecessary setting of `credentials` op...          False
# 3                                          Meta tweaks          False
# 4    Fix signal handling for Request objects (#613)...          False
# ..                                                 ...            ...
# 392           Add `prefixUrl` option (#11)\n\nFixes #1          False
# 393                        Fix usage example URL (#38)          False
# 394  Change `retry` option default to what's actual...          False
# 395                    Split tests into multiple files          False
# 396                                              0.3.0          False
#
#      predictedType
# 0            chore
# 1             feat
# 2              fix
# 3             docs
# 4              fix
# ..             ...
# 392           feat
# 393           docs
# 394            fix
# 395           test
# 396          chore
#
# [397 rows x 458 columns]

# %%
df_commits['predictedScore'] = flt.predict_proba(X)[:, 1]
df_commits
# Out:
# /tmp/ipykernel_188202/2212904620.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits['predictedScore'] = flt.predict_proba(X)[:, 1]
#                                           sha    nameWithOwner  \
# 0    a7204c4672d10a144b12ef169c8d38e17db81931  sindresorhus_ky
# 1    8531b050918d54066abb9f11b0193b893e77718f  sindresorhus_ky
# 2    fbe0ec68b052a9df6221a3531553783860925289  sindresorhus_ky
# 3    9728f4bd47a00f7aabb1be433c8879ec6e1e584c  sindresorhus_ky
# 4    2376cf2bdfc97cee92df220a51e69dd3ef700eef  sindresorhus_ky
# ..                                        ...              ...
# 392  66fb6c37921244ec7ca94068749effa4aa69c5cb  sindresorhus_ky
# 393  91de80f0b9b4db9760f6f247f5f5d8f1d1ab256a  sindresorhus_ky
# 394  81bbf7b6f6eed796b2f9c711ee96f5f298367818  sindresorhus_ky
# 395  6a32b54b61b2d6209ff048fa5b7b598c80032b7e  sindresorhus_ky
# 396  52bc75aaddc02b072b5d17d270e96dbd841d0810  sindresorhus_ky
#
#           authorName                                   authorEmail  \
# 0      Sindre Sorhus                        sindresorhus@gmail.com
# 1      Seth Holladay                          me@seth-holladay.com
# 2      Seth Holladay                          me@seth-holladay.com
# 3      Sindre Sorhus                        sindresorhus@gmail.com
# 4    Christian Owusu  36159205+crisshaker@users.noreply.github.com
# ..               ...                                           ...
# 392    Seth Holladay                          me@seth-holladay.com
# 393  Thijs Triemstra                                info@collab.nl
# 394    Sindre Sorhus                        sindresorhus@gmail.com
# 395    Sindre Sorhus                        sindresorhus@gmail.com
# 396    Sindre Sorhus                        sindresorhus@gmail.com
#
#                           date  nFiles  addLines  delLines  lang1CEnterprise  \
# 0    2024-08-13 11:19:59+02:00       1         1         1                 0
# 1    2024-08-12 19:27:37-04:00       4        74         3                 0
# 2    2024-08-10 17:29:40-04:00       1         0         5                 0
# 3    2024-08-08 15:06:10+02:00       1         0        14                 0
# 4    2024-07-31 18:04:40-04:00       2        21         7                 0
# ..                         ...     ...       ...       ...               ...
# 392  2018-09-30 01:30:24+07:00       4        81         1                 0
# 393  2018-09-30 01:28:55+07:00       1         1         1                 0
# 394  2018-09-17 19:20:09+07:00       1         1         1                 0
# 395  2018-09-17 13:14:28+07:00       6       163       148                 0
# 396  2018-09-17 12:12:48+07:00       1         1         1                 0
#
#      langAbap  ...  issues  prs  stars  comments   domain  type  \
# 0           0  ...     331  228  12834      2343  Library  None
# 1           0  ...     331  228  12834      2343  Library  None
# 2           0  ...     331  228  12834      2343  Library  None
# 3           0  ...     331  228  12834      2343  Library  None
# 4           0  ...     331  228  12834      2343  Library  None
# ..        ...  ...     ...  ...    ...       ...      ...   ...
# 392         0  ...     331  228  12834      2343  Library  None
# 393         0  ...     331  228  12834      2343  Library  None
# 394         0  ...     331  228  12834      2343  Library  None
# 395         0  ...     331  228  12834      2343  Library  None
# 396         0  ...     331  228  12834      2343  Library  None
#
#                                                   body  isMergeCommit  \
# 0                                                1.6.0          False
# 1    Add support for the `RateLimit-Reset` header (...          False
# 2    Remove unnecessary setting of `credentials` op...          False
# 3                                          Meta tweaks          False
# 4    Fix signal handling for Request objects (#613)...          False
# ..                                                 ...            ...
# 392           Add `prefixUrl` option (#11)\n\nFixes #1          False
# 393                        Fix usage example URL (#38)          False
# 394  Change `retry` option default to what's actual...          False
# 395                    Split tests into multiple files          False
# 396                                              0.3.0          False
#
#      predictedType  predictedScore
# 0            chore        0.784597
# 1             feat        0.994305
# 2              fix        0.991399
# 3             docs        0.939210
# 4              fix        0.993605
# ..             ...             ...
# 392           feat        0.966487
# 393           docs        0.978075
# 394            fix        0.981458
# 395           test        0.985879
# 396          chore        0.889982
#
# [397 rows x 459 columns]

# %%
def get_embeddings(df_s):
    with torch.no_grad():
        _df_embs = []
        # chunk df['body']
        for _texts in tqdm(np.array_split(
            df_s, len(df_commits) // settings.BATCH_SIZE)):
            _texts = _texts.tolist()
            batch_dict = tokenizer(
                _texts, max_length=8192, padding=True, truncation=True, return_tensors='pt'
            ).to(settings.TORCH_DEVICE)
            outputs = model(**batch_dict)
            embeddings = outputs.last_hidden_state[:, 0].cpu().detach().numpy()
            _df_embs.append(embeddings)
    return pd.concat([pd.DataFrame(_embs) for _embs in _df_embs], ignore_index=True)

# %%
def worker(name_with_owner: str, domain: Literal['Application', 'Library', 'System', 'Tool']) -> pd.DataFrame:
    df_commits = collect_features(name_with_owner, domain)
    df_embs = get_embeddings(df_commits['body'])
    df_ds = pd.concat([df_commits, df_embs], axis=1)\
        .drop(columns=['nameWithOwner', 'sha', 'authorName', 'authorEmail', 'date', 'releaseTag', 'body'])

    df_ds['releaseType'] = pd.Series(_encode_releaseType.transform(df_ds['releaseType'])).astype('category')
    df_ds['domain'] = pd.Series(_encoder_domain.transform(df_ds['domain'])).astype('category')

    y_pred = clf.predict(df_ds.drop(columns=['type']))
    df_commits['predictedType'] = _encoder_type.inverse_transform(y_pred)
    df_commits['predictedScore'] = flt.predict_proba(df_ds.drop(columns=['type']))[:, 1]
    df_commits.to_parquet(settings.DATASETS_PATH / f'eval_{name_with_owner.replace("/", "_")}.parquet')
    return df_commits

worker('sindresorhus/ky', 'Library')
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Fetching releases: 100%|██████████| 73/73 [00:02<00:00, 29.55it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:39:52.108 | WARNING  | calculate_stats:get_commit_stats:109 - Found 73 releases in sindresorhus_ky
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:39:52.347 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.5.0...v1.6.0 (1/72): 7 commits
# v1.5.0...v1.6.0:   0%|          | 0/7 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0:  14%|█▍        | 1/7 [00:00<00:02,  2.91it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0:  29%|██▊       | 2/7 [00:00<00:01,  3.43it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0:  43%|████▎     | 3/7 [00:00<00:01,  3.55it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0:  57%|█████▋    | 4/7 [00:01<00:00,  3.72it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0:  71%|███████▏  | 5/7 [00:01<00:00,  3.83it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0:  86%|████████▌ | 6/7 [00:01<00:00,  3.88it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.5.0...v1.6.0: 100%|██████████| 7/7 [00:01<00:00,  3.75it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:39:54.571 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.4.0...v1.5.0 (2/72): 8 commits
# v1.4.0...v1.5.0:   0%|          | 0/8 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  12%|█▎        | 1/8 [00:00<00:02,  3.31it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  25%|██▌       | 2/8 [00:00<00:01,  3.68it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  38%|███▊      | 3/8 [00:00<00:01,  3.90it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  50%|█████     | 4/8 [00:01<00:00,  4.07it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  62%|██████▎   | 5/8 [00:01<00:00,  4.12it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  75%|███████▌  | 6/8 [00:01<00:00,  4.10it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0:  88%|████████▊ | 7/8 [00:01<00:00,  4.18it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.4.0...v1.5.0: 100%|██████████| 8/8 [00:01<00:00,  4.06it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:39:56.897 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.3.0...v1.4.0 (3/72): 8 commits
# v1.3.0...v1.4.0:   0%|          | 0/8 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  12%|█▎        | 1/8 [00:00<00:02,  3.24it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  25%|██▌       | 2/8 [00:00<00:01,  3.70it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  38%|███▊      | 3/8 [00:00<00:01,  3.87it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  50%|█████     | 4/8 [00:01<00:01,  3.99it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  62%|██████▎   | 5/8 [00:01<00:00,  4.02it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  75%|███████▌  | 6/8 [00:01<00:00,  4.05it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0:  88%|████████▊ | 7/8 [00:01<00:00,  4.07it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.3.0...v1.4.0: 100%|██████████| 8/8 [00:01<00:00,  4.03it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:39:59.227 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.4...v1.3.0 (4/72): 5 commits
# v1.2.4...v1.3.0:   0%|          | 0/5 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.4...v1.3.0:  20%|██        | 1/5 [00:00<00:01,  3.40it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.4...v1.3.0:  40%|████      | 2/5 [00:00<00:00,  3.93it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.4...v1.3.0:  60%|██████    | 3/5 [00:00<00:00,  4.16it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.4...v1.3.0:  80%|████████  | 4/5 [00:00<00:00,  4.26it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.4...v1.3.0: 100%|██████████| 5/5 [00:01<00:00,  4.06it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:40:00.800 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.3...v1.2.4 (5/72): 7 commits
# v1.2.3...v1.2.4:   0%|          | 0/7 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4:  14%|█▍        | 1/7 [00:00<00:01,  3.36it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4:  29%|██▊       | 2/7 [00:00<00:01,  3.94it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4:  43%|████▎     | 3/7 [00:00<00:00,  4.20it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4:  57%|█████▋    | 4/7 [00:00<00:00,  4.35it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4:  71%|███████▏  | 5/7 [00:01<00:00,  4.33it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4:  86%|████████▌ | 6/7 [00:01<00:00,  4.40it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v1.2.3...v1.2.4: 100%|██████████| 7/7 [00:01<00:00,  4.30it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:40:02.933 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v1.2.2...v1.2.3 (6/72): 3 commits
# ...
#   data[k] = com.apply_if_callable(v, data)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-08-14 23:41:56.084 | INFO     | calculate_stats:get_commit_stats:130 - sindresorhus_ky: Analyzing v0.3.0...v0.4.0 (72/72): 7 commits
# v0.3.0...v0.4.0:   0%|          | 0/7 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0:  14%|█▍        | 1/7 [00:00<00:01,  3.45it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0:  29%|██▊       | 2/7 [00:00<00:01,  3.91it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0:  43%|████▎     | 3/7 [00:00<00:00,  4.25it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0:  57%|█████▋    | 4/7 [00:00<00:00,  4.31it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0:  71%|███████▏  | 5/7 [00:01<00:00,  4.46it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0:  86%|████████▌ | 6/7 [00:01<00:00,  4.53it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# v0.3.0...v0.4.0: 100%|██████████| 7/7 [00:01<00:00,  4.38it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:3641: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]
# /tmp/ipykernel_188202/2415618806.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits['isMergeCommit'] = df_commits['message'].apply(is_merge_commit)
# /tmp/ipykernel_188202/2415618806.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits.reset_index(inplace=True)
# 100%|██████████| 12/12 [00:00<00:00, 14.86it/s]
# /tmp/ipykernel_188202/770185806.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits['predictedType'] = _encoder_type.inverse_transform(y_pred)
# /tmp/ipykernel_188202/770185806.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_commits['predictedScore'] = flt.predict_proba(df_ds.drop(columns=['type']))[:, 1]
#                                           sha    nameWithOwner  \
# 0    a7204c4672d10a144b12ef169c8d38e17db81931  sindresorhus_ky
# 1    8531b050918d54066abb9f11b0193b893e77718f  sindresorhus_ky
# 2    fbe0ec68b052a9df6221a3531553783860925289  sindresorhus_ky
# 3    9728f4bd47a00f7aabb1be433c8879ec6e1e584c  sindresorhus_ky
# 4    2376cf2bdfc97cee92df220a51e69dd3ef700eef  sindresorhus_ky
# ..                                        ...              ...
# 392  66fb6c37921244ec7ca94068749effa4aa69c5cb  sindresorhus_ky
# 393  91de80f0b9b4db9760f6f247f5f5d8f1d1ab256a  sindresorhus_ky
# 394  81bbf7b6f6eed796b2f9c711ee96f5f298367818  sindresorhus_ky
# 395  6a32b54b61b2d6209ff048fa5b7b598c80032b7e  sindresorhus_ky
# 396  52bc75aaddc02b072b5d17d270e96dbd841d0810  sindresorhus_ky
#
#           authorName                                   authorEmail  \
# 0      Sindre Sorhus                        sindresorhus@gmail.com
# 1      Seth Holladay                          me@seth-holladay.com
# 2      Seth Holladay                          me@seth-holladay.com
# 3      Sindre Sorhus                        sindresorhus@gmail.com
# 4    Christian Owusu  36159205+crisshaker@users.noreply.github.com
# ..               ...                                           ...
# 392    Seth Holladay                          me@seth-holladay.com
# 393  Thijs Triemstra                                info@collab.nl
# 394    Sindre Sorhus                        sindresorhus@gmail.com
# 395    Sindre Sorhus                        sindresorhus@gmail.com
# 396    Sindre Sorhus                        sindresorhus@gmail.com
#
#                           date  nFiles  addLines  delLines  lang1CEnterprise  \
# 0    2024-08-13 11:19:59+02:00       1         1         1                 0
# 1    2024-08-12 19:27:37-04:00       4        74         3                 0
# 2    2024-08-10 17:29:40-04:00       1         0         5                 0
# 3    2024-08-08 15:06:10+02:00       1         0        14                 0
# 4    2024-07-31 18:04:40-04:00       2        21         7                 0
# ..                         ...     ...       ...       ...               ...
# 392  2018-09-30 01:30:24+07:00       4        81         1                 0
# 393  2018-09-30 01:28:55+07:00       1         1         1                 0
# 394  2018-09-17 19:20:09+07:00       1         1         1                 0
# 395  2018-09-17 13:14:28+07:00       6       163       148                 0
# 396  2018-09-17 12:12:48+07:00       1         1         1                 0
#
#      langAbap  ...  issues  prs  stars  comments   domain  type  \
# 0           0  ...     331  228  12834      2343  Library  None
# 1           0  ...     331  228  12834      2343  Library  None
# 2           0  ...     331  228  12834      2343  Library  None
# 3           0  ...     331  228  12834      2343  Library  None
# 4           0  ...     331  228  12834      2343  Library  None
# ..        ...  ...     ...  ...    ...       ...      ...   ...
# 392         0  ...     331  228  12834      2343  Library  None
# 393         0  ...     331  228  12834      2343  Library  None
# 394         0  ...     331  228  12834      2343  Library  None
# 395         0  ...     331  228  12834      2343  Library  None
# 396         0  ...     331  228  12834      2343  Library  None
#
#                                                   body  isMergeCommit  \
# 0                                                1.6.0          False
# 1    Add support for the `RateLimit-Reset` header (...          False
# 2    Remove unnecessary setting of `credentials` op...          False
# 3                                          Meta tweaks          False
# 4    Fix signal handling for Request objects (#613)...          False
# ..                                                 ...            ...
# 392           Add `prefixUrl` option (#11)\n\nFixes #1          False
# 393                        Fix usage example URL (#38)          False
# 394  Change `retry` option default to what's actual...          False
# 395                    Split tests into multiple files          False
# 396                                              0.3.0          False
#
#      predictedType  predictedScore
# 0            chore        0.784597
# 1             feat        0.994305
# 2              fix        0.991399
# 3             docs        0.939210
# 4              fix        0.993605
# ..             ...             ...
# 392           feat        0.966487
# 393           docs        0.978075
# 394            fix        0.981458
# 395           test        0.985879
# 396          chore        0.889982
#
# [397 rows x 459 columns]

# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# %%
import multiprocess
import tqdm.auto as tqdm

df_repos = pd.read_csv(settings.DATASETS_PATH / 'eval_gh_repos.csv')
repos = df_repos['URL'].apply(lambda x: '/'.join(x.split('/')[-2:])).tolist()
domains = df_repos['Project Domain'].tolist()

# map full domaains to short domains
_map = {
    'Application Software': 'Application',
    'System Software': 'System',
    'Libraries & Frameworks': 'Library',
    'Software Tool': 'Tool'
}
domains = [_map[_] for _ in domains]

with multiprocess.Pool(8) as pool:
    for _ in tqdm.tqdm(pool.imap_unordered(lambda x: worker(*x), zip(repos, domains)), total=len(repos)):
        pass
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# Fetching releases: 100%|██████████| 19/19 [00:01<00:00, 16.47it/s]
# 2024-08-14 23:45:56.051 | WARNING  | calculate_stats:get_commit_stats:109 - Found 19 releases in rustdesk_rustdesk
# 2024-08-14 23:45:56.299 | INFO     | calculate_stats:get_commit_stats:130 - rustdesk_rustdesk: Analyzing 1.2.7...nightly (1/18): 40 commits
# Fetching releases: 100%|██████████| 9/9 [00:01<00:00,  7.17it/s]/s]
# 1.2.7...nightly:  18%|█▊        | 7/40 [00:01<00:08,  4.11it/s]2024-08-14 23:45:58.247 | WARNING  | calculate_stats:get_commit_stats:109 - Found 9 releases in comfyanonymous_ComfyUI
# 2024-08-14 23:45:58.481 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.7...v0.0.8 (1/8): 6 commits
# v0.0.7...v0.0.8: 100%|██████████| 6/6 [00:01<00:00,  3.67it/s]s]/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.7...nightly:  38%|███▊      | 15/40 [00:03<00:06,  3.92it/s]2024-08-14 23:46:00.470 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.6...v0.0.7 (2/8): 14 commits
# Fetching releases: 100%|██████████| 220/220 [00:08<00:00, 26.56it/s]
# v0.0.6...v0.0.7:  86%|████████▌ | 12/14 [00:03<00:00,  2.99it/s]2024-08-14 23:46:04.161 | WARNING  | calculate_stats:get_commit_stats:109 - Found 220 releases in vuejs_core
# v0.0.6...v0.0.7:  93%|█████████▎| 13/14 [00:03<00:00,  3.09it/s]2024-08-14 23:46:04.428 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.37...v3.5.0-beta.1 (1/219): 5 commits
# v0.0.6...v0.0.7: 100%|██████████| 14/14 [00:04<00:00,  3.44it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v3.4.37...v3.5.0-beta.1:  20%|██        | 1/5 [00:00<00:01,  2.38it/s]2024-08-14 23:46:04.970 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.5...v0.0.6 (3/8): 5 commits
# v3.4.37...v3.5.0-beta.1: 100%|██████████| 5/5 [00:01<00:00,  3.89it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v0.0.5...v0.0.6:  60%|██████    | 3/5 [00:00<00:00,  3.29it/s]s]2024-08-14 23:46:06.114 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.36...v3.4.37 (2/219): 28 commits
# v0.0.5...v0.0.6: 100%|██████████| 5/5 [00:01<00:00,  3.41it/s]s]
# 1.2.7...nightly:  92%|█████████▎| 37/40 [00:10<00:00,  3.35it/s]]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.7...nightly:  95%|█████████▌| 38/40 [00:10<00:00,  3.50it/s]]2024-08-14 23:46:07.108 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.4...v0.0.5 (4/8): 31 commits
# 1.2.7...nightly: 100%|██████████| 40/40 [00:11<00:00,  3.55it/s]]
# v0.0.4...v0.0.5:   6%|▋         | 2/31 [00:00<00:08,  3.58it/s]2024-08-14 23:46:07.695 | DEBUG    | calculate_stats:infer_release_type:43 - Error in parsing version: 1.2.7, nightly, leave as Unknown
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v0.0.4...v0.0.5:  10%|▉         | 3/31 [00:00<00:07,  3.79it/s]s]2024-08-14 23:46:07.966 | INFO     | calculate_stats:get_commit_stats:130 - rustdesk_rustdesk: Analyzing 1.2.6...1.2.7 (2/18): 197 commits
# v3.4.36...v3.4.37: 100%|██████████| 28/28 [00:07<00:00,  3.76it/s]
# 1.2.6...1.2.7:  11%|█         | 21/197 [00:05<00:45,  3.87it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.6...1.2.7:  11%|█         | 22/197 [00:05<00:44,  3.93it/s]]2024-08-14 23:46:13.917 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.5.0-alpha.5...v3.4.36 (3/219): 0 commits
# v3.5.0-alpha.5...v3.4.36: 0it [00:00, ?it/s]
# 2024-08-14 23:46:13.923 | WARNING  | calculate_stats:get_commit_stats:193 - No commits in vuejs_core - v3.5.0-alpha.5...v3.4.36
# v0.0.4...v0.0.5:  90%|█████████ | 28/31 [00:07<00:00,  4.07it/s]2024-08-14 23:46:14.197 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.35...v3.5.0-alpha.5 (4/219): 3 commits
# v3.4.35...v3.5.0-alpha.5: 100%|██████████| 3/3 [00:00<00:00,  4.93it/s]
# v0.0.4...v0.0.5: 100%|██████████| 31/31 [00:07<00:00,  3.91it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# Fetching releases:   1%|▏         | 1/71 [00:01<01:42,  1.46s/it]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 2024-08-14 23:46:15.452 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.3...v0.0.4 (5/8): 0 commits
# v0.0.3...v0.0.4: 0it [00:00, ?it/s]
# 2024-08-14 23:46:15.459 | WARNING  | calculate_stats:get_commit_stats:193 - No commits in comfyanonymous_ComfyUI - v0.0.3...v0.0.4
# 1.2.6...1.2.7:  14%|█▍        | 28/197 [00:07<00:46,  3.61it/s]2024-08-14 23:46:15.596 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.5.0-alpha.4...v3.4.35 (5/219): 0 commits
# v3.5.0-alpha.4...v3.4.35: 0it [00:00, ?it/s]
# 2024-08-14 23:46:15.604 | WARNING  | calculate_stats:get_commit_stats:193 - No commits in vuejs_core - v3.5.0-alpha.4...v3.4.35
# 2024-08-14 23:46:15.733 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.2...v0.0.3 (6/8): 36 commits
# 1.2.6...1.2.7:  15%|█▍        | 29/197 [00:07<00:46,  3.64it/s]2024-08-14 23:46:15.936 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.34...v3.5.0-alpha.4 (6/219): 3 commits
# v3.4.34...v3.5.0-alpha.4: 100%|██████████| 3/3 [00:00<00:00,  4.05it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# Fetching releases:  44%|████▎     | 31/71 [00:03<00:03, 11.27it/s]2024-08-14 23:46:17.128 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.5.0-alpha.3...v3.4.34 (7/219): 0 commits
# v3.5.0-alpha.3...v3.4.34: 0it [00:00, ?it/s]9<00:44,  3.68it/s]
# 2024-08-14 23:46:17.135 | WARNING  | calculate_stats:get_commit_stats:193 - No commits in vuejs_core - v3.5.0-alpha.3...v3.4.34
# 1.2.6...1.2.7:  18%|█▊        | 35/197 [00:09<00:44,  3.68it/s]2024-08-14 23:46:17.448 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.33...v3.5.0-alpha.3 (8/219): 3 commits
# v3.4.33...v3.5.0-alpha.3: 100%|██████████| 3/3 [00:00<00:00,  4.62it/s]
# Fetching releases: 100%|██████████| 71/71 [00:04<00:00, 16.14it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v0.0.2...v0.0.3:  25%|██▌       | 9/36 [00:02<00:07,  3.58it/s]2024-08-14 23:46:18.420 | WARNING  | calculate_stats:get_commit_stats:109 - Found 71 releases in WerWolv_ImHex
# 2024-08-14 23:46:18.456 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.32...v3.4.33 (9/219): 5 commits
# v0.0.2...v0.0.3:  28%|██▊       | 10/36 [00:02<00:07,  3.57it/s]2024-08-14 23:46:18.711 | INFO     | calculate_stats:get_commit_stats:130 - WerWolv_ImHex: Analyzing v1.35.3...v1.35.4 (1/70): 35 commits
# v3.4.32...v3.4.33: 100%|██████████| 5/5 [00:01<00:00,  3.13it/s]]
# v1.35.3...v1.35.4:  11%|█▏        | 4/35 [00:01<00:10,  2.88it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.6...1.2.7:  23%|██▎       | 46/197 [00:12<00:39,  3.80it/s]s]2024-08-14 23:46:20.447 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.31...v3.4.32 (10/219): 51 commits
# v0.0.2...v0.0.3: 100%|██████████| 36/36 [00:10<00:00,  3.58it/s]s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v1.35.3...v1.35.4:  74%|███████▍  | 26/35 [00:07<00:02,  3.74it/s]2024-08-14 23:46:26.159 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing v0.0.1...v0.0.2 (7/8): 5 commits
# v0.0.1...v0.0.2: 100%|██████████| 5/5 [00:01<00:00,  3.77it/s]t/s]
# v3.4.31...v3.4.32:  53%|█████▎    | 27/51 [00:07<00:06,  3.68it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.6...1.2.7:  38%|███▊      | 75/197 [00:20<00:31,  3.82it/s]/s]2024-08-14 23:46:28.079 | INFO     | calculate_stats:get_commit_stats:130 - comfyanonymous_ComfyUI: Analyzing latest...v0.0.1 (8/8): 1472 commits
# v1.35.3...v1.35.4: 100%|██████████| 35/35 [00:09<00:00,  3.50it/s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v3.4.31...v3.4.32:  63%|██████▎   | 32/51 [00:08<00:05,  3.54it/s]2024-08-14 23:46:29.114 | INFO     | calculate_stats:get_commit_stats:130 - WerWolv_ImHex: Analyzing v1.35.2...v1.35.3 (2/70): 4 commits
# v1.35.2...v1.35.3: 100%|██████████| 4/4 [00:01<00:00,  3.03it/s]]]
# 1.2.6...1.2.7:  43%|████▎     | 84/197 [00:22<00:34,  3.27it/s]s]]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# latest...v0.0.1:   1%|          | 10/1472 [00:02<07:09,  3.41it/s]2024-08-14 23:46:31.081 | INFO     | calculate_stats:get_commit_stats:130 - WerWolv_ImHex: Analyzing v1.35.1...v1.35.2 (3/70): 4 commits
# Fetching releases: 100%|██████████| 12/12 [00:00<00:00, 12.04it/s]
# v1.35.1...v1.35.2:  50%|█████     | 2/4 [00:00<00:00,  2.85it/s]s]2024-08-14 23:46:31.902 | WARNING  | calculate_stats:get_commit_stats:109 - Found 12 releases in reworkd_AgentGPT
# latest...v0.0.1:   1%|          | 14/1472 [00:04<07:14,  3.36it/s]2024-08-14 23:46:32.226 | INFO     | calculate_stats:get_commit_stats:130 - reworkd_AgentGPT: Analyzing v.0.10.0-beta...v.1.0.0 (1/11): 290 commits
# v1.35.1...v1.35.2: 100%|██████████| 4/4 [00:01<00:00,  3.19it/s]s]
# /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.6...1.2.7:  46%|████▌     | 91/197 [00:24<00:27,  3.81it/s]6.38it/s]2024-08-14 23:46:32.710 | INFO     | calculate_stats:get_commit_stats:130 - WerWolv_ImHex: Analyzing v1.35.0...v1.35.1 (4/70): 3 commits
# v1.35.0...v1.35.1: 100%|██████████| 3/3 [00:00<00:00,  3.19it/s].20it/s]
# v3.4.31...v3.4.32:  98%|█████████▊| 50/51 [00:13<00:00,  3.94it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v3.4.31...v3.4.32: 100%|██████████| 51/51 [00:13<00:00,  3.76it/s]7it/s]
# 2024-08-14 23:46:34.043 | INFO     | calculate_stats:get_commit_stats:130 - WerWolv_ImHex: Analyzing v1.34.0...v1.35.0 (5/70): 133 commits
# v.0.10.0-beta...v.1.0.0:   3%|▎         | 8/290 [00:01<01:09,  4.07it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v.0.10.0-beta...v.1.0.0:   3%|▎         | 9/290 [00:02<01:09,  4.03it/s]2024-08-14 23:46:34.417 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.30...v3.4.31 (11/219): 18 commits
# Fetching releases: 100%|██████████| 83/83 [00:05<00:00, 16.05it/s]10it/s]
# v3.4.30...v3.4.31:  33%|███▎      | 6/18 [00:01<00:03,  3.76it/s]]74it/s]2024-08-14 23:46:36.107 | WARNING  | calculate_stats:get_commit_stats:109 - Found 83 releases in beekeeper-studio_beekeeper-studio
# latest...v0.0.1:   2%|▏         | 30/1472 [00:08<06:17,  3.82it/s]50it/s]2024-08-14 23:46:36.357 | INFO     | calculate_stats:get_commit_stats:130 - beekeeper-studio_beekeeper-studio: Analyzing v4.6.0...v4.6.2 (1/82): 31 commits
# v3.4.30...v3.4.31: 100%|██████████| 18/18 [00:04<00:00,  3.66it/s]]9it/s]
# v4.6.0...v4.6.2:  55%|█████▍    | 17/31 [00:03<00:03,  4.26it/s]3.66it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# v4.6.0...v4.6.2:  58%|█████▊    | 18/31 [00:03<00:03,  3.98it/s]3.74it/s]2024-08-14 23:46:39.725 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.29...v3.4.30 (12/219): 21 commits
# v4.6.0...v4.6.2: 100%|██████████| 31/31 [00:06<00:00,  5.09it/s]]]]7it/s]
# v3.4.29...v3.4.30:  48%|████▊     | 10/21 [00:02<00:03,  3.48it/s]]1it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# 1.2.6...1.2.7:  65%|██████▍   | 128/197 [00:34<00:23,  2.88it/s]s]]3it/s]2024-08-14 23:46:43.049 | INFO     | calculate_stats:get_commit_stats:130 - beekeeper-studio_beekeeper-studio: Analyzing v4.3.4...v4.6.0 (2/82): 124 commits
# v3.4.29...v3.4.30: 100%|██████████| 21/21 [00:06<00:00,  3.41it/s]20it/s]
# v1.34.0...v1.35.0:  30%|███       | 40/133 [00:11<00:31,  2.94it/s]/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py:4486: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[k] = com.apply_if_callable(v, data)
# latest...v0.0.1:   4%|▍         | 66/1472 [00:18<06:37,  3.54it/s]31it/s]2024-08-14 23:46:46.292 | INFO     | calculate_stats:get_commit_stats:130 - vuejs_core: Analyzing v3.4.28...v3.4.29 (13/219): 11 commits
# Fetching releases: 0it [00:00, ?it/s]97 [00:38<00:16,  3.50it/s]]s]1it/s]
# 2024-08-14 23:46:46.754 | WARNING  | calculate_stats:get_commit_stats:109 - Found 0 releases in mackron_miniaudio
# 2024-08-14 23:46:46.756 | WARNING  | calculate_stats:get_commit_stats:111 - Less than 2 releases in mackron_miniaudio
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3361, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 76, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 5198, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 5206, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'message'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_188202/2802138312.py", line 18, in <lambda>
#     for _ in tqdm.tqdm(pool.imap_unordered(lambda x: worker(*x), zip(repos, domains)), total=len(repos)):
#   File "/tmp/ipykernel_188202/770185806.py", line 2, in worker
#     df_commits = collect_features(name_with_owner, domain)
#   File "/tmp/ipykernel_188202/2415618806.py", line 25, in collect_features
#     df_commits['message'].apply(lambda x: pd.Series(parse_commit_message(x), index=['type', 'body']))
#   File "/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/frame.py", line 3458, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 3363, in get_loc
#     raise KeyError(key) from err
# KeyError: 'message'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 18
#      15 domains = [_map[_] for _ in domains]
#      17 with multiprocess.Pool(8) as pool:
# ---> 18     for _ in tqdm.tqdm(pool.imap_unordered(lambda x: worker(*x), zip(repos, domains)), total=len(repos)):
#      19         pass
#
# File /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/tqdm/notebook.py:259, in tqdm_notebook.__iter__(self)
#     257 try:
#     258     it = super(tqdm_notebook, self).__iter__()
# --> 259     for obj in it:
#     260         # return super(tqdm...) will not catch exception
#     261         yield obj
#     262 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File /raid/hrz/smartdraft/.pixi/envs/default/lib/python3.9/site-packages/multiprocess/pool.py:870, in IMapIterator.next(self, timeout)
#     868 if success:
#     869     return value
# --> 870 raise value
#
# KeyError: 'message'
