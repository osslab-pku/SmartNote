# %%
from openai import OpenAI

# read openai token from token.txt
with open('token.txt', 'r') as file:
    token = file.read().replace('\n', '')

openai = OpenAI(api_key=token)

def get_first_response(prompt):
    response = openai.chat.completions.create(
        model="gpt-4o",
        temperature=0,
        top_p=0.1,
        messages=prompt,
    )
    return response.choices[0].message.content

get_first_response([
    {
        "role": "system",
        "content": "You are a helpful assistant."
    },
    {
        "role": "user",
        "content": "What is the capital of the United States?"
    }
])
# Out:
# 'The capital of the United States is Washington, D.C.'

# %%
from typing import List

def is_commit_message_good(
    commit_message: str
) -> bool:
    """
    Guide GPT to determine whether commit messages are 'good' based on Yuxia's taxonomy
    of good commit messages (https://arxiv.org/pdf/2202.02974). In short, a commit message
    is considered good if it describes 'what' and 'why'.
    """
    prompt = [
        {
            "role": "system",
            "content": str(
                "You will be provided with a commit message."
                "From the provided data, determine if the commit message is of high quality and relevant to the project."
                "A good commit message describes 'what' (summarize the change and the design decisions) "
                "and 'why' (what is the problem, what is the goal of the change, and why the change is necessary). "
                "\nExamples of good commit messages: "
                "\n- Remove outdated key. `aggregate-key-pattern` is no longer defined but was still referenced in the documentation."
                "\n- Fix concurrent problem of zookeeper configcenter, wait to start until cache being fully populated."
                "\n- Polish pom.xml. Apply consistent formatting, drop JDK 8 support and cleanup repo."
                "\nExamples of bad commit messages: "
                "\n- Update README.md"
                "\n- Fix bug"
                "\n- A lot of changes"
                "\n\nYour response must be a 'yes' or 'no' answer."
                "\n\nDo not format your response in anyway."
            ),
        },
        {"role": "user", "content": commit_message},
    ]
    _response = get_first_response(prompt)
    if _response.strip().lower() == "no":
        return False
    if _response.strip().lower() == "yes":
        return True
    return False

is_commit_message_good("log message")
# Out:
# False

# %%
import pandas as pd

df = pd.read_csv('sampled messages.csv', index_col=0)
df
# Out:
#        repo_id  label                                                url  \
# id
# 1            1      0  https://github.com/junit-team/junit4/commit/12...
# 27           1      0  https://github.com/junit-team/junit4/commit/43...
# 38           1      3  https://github.com/junit-team/junit4/commit/6c...
# 56           1      0  https://github.com/junit-team/junit4/commit/46...
# 66           1      0  https://github.com/junit-team/junit4/commit/8a...
# ...        ...    ...                                                ...
# 29726        5      2  https://github.com/spring-projects/spring-boot...
# 29742        5      0  https://github.com/spring-projects/spring-boot...
# 29756        5      0  https://github.com/spring-projects/spring-boot...
# 29769        5      0  https://github.com/spring-projects/spring-boot...
# 29846        5      0  https://github.com/spring-projects/spring-boot...
#
#        if_mulit_commit                                            message  \
# id
# 1                  NaN  Mark ThreadGroups created by FailOnTimeout as ...
# 27                 NaN  Use Google's Maven Central mirror <enter>  <en...
# 38                 NaN          Remove reference to obsolete mailing list
# 56                 NaN  Deprecate Assert#assertThat <enter>  <enter> T...
# 66                 NaN  Revert 'ExternalResource: declare after() to t...
# ...                ...                                                ...
# 29726              NaN                              Fix checkstyle errors
# 29742              NaN  Remove dependency management for `hibernate-en...
# 29756              NaN  Support reactive web servers with LocalServerP...
# 29769              NaN  Upgrade to Rxjava2 2.0.6 <enter>  <enter> Clos...
# 29846              NaN  Add byte-buddy managed dependency <enter>  <en...
#
#                                             new_message1      authorName  \
# id
# 1      Mark ThreadGroups created by  <file_name>  as ...    Kevin Cooney
# 27     Use Google's <iden> mirror  <enter> We are usi...  Stefan Birkner
# 38            Remove reference to obsolete mailing list     Marc Philipp
# 56     Deprecate  <method_name> <enter> The method <i...  Stefan Birkner
# 66     Revert ' <file_name> : declare after() to thro...  Alex Panchenko
# ...                                                  ...             ...
# 29726                             Fix checkstyle errors     Phillip Webb
# 29742  Remove dependency management for `hibernate-en...    Vedran Pavic
# 29756  Support reactive web servers with LocalServerP...    Brian Clozel
# 29769  Upgrade to Rxjava2 <version>  <enter> Closes <...  Andy Wilkinson
# 29846  Add byte-buddy managed dependency  <enter> Add...    Phillip Webb
#
#                             authorEmail            commitDate  \
# id
# 1      kcooney@users.noreply.github.com  2021-01-02T22:09:07Z
# 27               mail@stefan-birkner.de  2020-02-07T20:35:25Z
# 38                  mail@marcphilipp.de  2019-11-02T13:05:11Z
# 56               mail@stefan-birkner.de  2019-09-26T20:24:47Z
# 66             alex.panchenko@gmail.com  2019-04-03T15:20:00Z
# ...                                 ...                   ...
# 29726                  pwebb@pivotal.io  2017-03-07T01:37:09Z
# 29742            vedran.pavic@gmail.com  2017-02-28T07:17:55Z
# 29756                bclozel@pivotal.io  2017-02-22T13:29:59Z
# 29769             awilkinson@pivotal.io  2017-02-22T15:06:16Z
# 29846                  pwebb@pivotal.io  2017-01-06T04:04:48Z
#
#          committerName          committerEmail         committerDate
# id
# 1               GitHub      noreply@github.com  2021-01-02T22:09:07Z
# 27        Marc Philipp         marc@gradle.com  2020-02-19T10:13:01Z
# 38        Marc Philipp     mail@marcphilipp.de  2019-11-02T13:05:11Z
# 56      Stefan Birkner  mail@stefan-birkner.de  2019-10-13T18:24:00Z
# 66        Marc Philipp         marc@gradle.com  2019-04-04T09:22:28Z
# ...                ...                     ...                   ...
# 29726     Phillip Webb        pwebb@pivotal.io  2017-03-07T01:37:09Z
# 29742  Stephane Nicoll      snicoll@pivotal.io  2017-03-02T17:31:53Z
# 29756     Brian Clozel      bclozel@pivotal.io  2017-02-24T12:03:11Z
# 29769   Andy Wilkinson   awilkinson@pivotal.io  2017-02-22T15:06:16Z
# 29846     Phillip Webb        pwebb@pivotal.io  2017-01-06T04:04:48Z
#
# [1649 rows x 12 columns]

# %%
from tqdm import tqdm

for i, row in tqdm(df.iterrows(), total=df.shape[0]):
    try:
        df.loc[i, 'is_good'] = is_commit_message_good(row['message'])
    except Exception as e:
        print(f"Error: {e}")
        df.loc[i, 'is_good'] = None
# Out:
# 100%|██████████| 1649/1649 [13:25<00:00,  2.05it/s]

# %%
# save df
df.to_csv('is_good.csv')

# %%
df[df['is_good'] == True]
# Out:
#        repo_id  label                                                url  \
# id
# 1            1      0  https://github.com/junit-team/junit4/commit/12...
# 27           1      0  https://github.com/junit-team/junit4/commit/43...
# 38           1      3  https://github.com/junit-team/junit4/commit/6c...
# 56           1      0  https://github.com/junit-team/junit4/commit/46...
# 66           1      0  https://github.com/junit-team/junit4/commit/8a...
# ...        ...    ...                                                ...
# 29594        5      0  https://github.com/spring-projects/spring-boot...
# 29674        5      0  https://github.com/spring-projects/spring-boot...
# 29742        5      0  https://github.com/spring-projects/spring-boot...
# 29756        5      0  https://github.com/spring-projects/spring-boot...
# 29846        5      0  https://github.com/spring-projects/spring-boot...
#
#        if_mulit_commit                                            message  \
# id
# 1                  NaN  Mark ThreadGroups created by FailOnTimeout as ...
# 27                 NaN  Use Google's Maven Central mirror <enter>  <en...
# 38                 NaN          Remove reference to obsolete mailing list
# 56                 NaN  Deprecate Assert#assertThat <enter>  <enter> T...
# 66                 NaN  Revert 'ExternalResource: declare after() to t...
# ...                ...                                                ...
# 29594              NaN  Align with Spring Framework 5's new Commons Lo...
# 29674              NaN  Align with API changes in latest Spring Data K...
# 29742              NaN  Remove dependency management for `hibernate-en...
# 29756              NaN  Support reactive web servers with LocalServerP...
# 29846              NaN  Add byte-buddy managed dependency <enter>  <en...
#
#                                             new_message1      authorName  \
# id
# 1      Mark ThreadGroups created by  <file_name>  as ...    Kevin Cooney
# 27     Use Google's <iden> mirror  <enter> We are usi...  Stefan Birkner
# 38            Remove reference to obsolete mailing list     Marc Philipp
# 56     Deprecate  <method_name> <enter> The method <i...  Stefan Birkner
# 66     Revert ' <file_name> : declare after() to thro...  Alex Panchenko
# ...                                                  ...             ...
# 29594  Align with <iden> Framework 5's new Commons <i...  Andy Wilkinson
# 29674  Align with API changes in latest Spring <iden>...  Andy Wilkinson
# 29742  Remove dependency management for `hibernate-en...    Vedran Pavic
# 29756  Support reactive web servers with LocalServerP...    Brian Clozel
# 29846  Add byte-buddy managed dependency  <enter> Add...    Phillip Webb
#
#                             authorEmail            commitDate  \
# id
# 1      kcooney@users.noreply.github.com  2021-01-02T22:09:07Z
# 27               mail@stefan-birkner.de  2020-02-07T20:35:25Z
# 38                  mail@marcphilipp.de  2019-11-02T13:05:11Z
# 56               mail@stefan-birkner.de  2019-09-26T20:24:47Z
# 66             alex.panchenko@gmail.com  2019-04-03T15:20:00Z
# ...                                 ...                   ...
# 29594             awilkinson@pivotal.io  2017-04-06T12:22:53Z
# 29674             awilkinson@pivotal.io  2017-03-24T11:26:27Z
# 29742            vedran.pavic@gmail.com  2017-02-28T07:17:55Z
# 29756                bclozel@pivotal.io  2017-02-22T13:29:59Z
# 29846                  pwebb@pivotal.io  2017-01-06T04:04:48Z
#
#          committerName          committerEmail         committerDate is_good
# id
# 1               GitHub      noreply@github.com  2021-01-02T22:09:07Z    True
# 27        Marc Philipp         marc@gradle.com  2020-02-19T10:13:01Z    True
# 38        Marc Philipp     mail@marcphilipp.de  2019-11-02T13:05:11Z    True
# 56      Stefan Birkner  mail@stefan-birkner.de  2019-10-13T18:24:00Z    True
# 66        Marc Philipp         marc@gradle.com  2019-04-04T09:22:28Z    True
# ...                ...                     ...                   ...     ...
# 29594   Andy Wilkinson   awilkinson@pivotal.io  2017-04-06T12:22:53Z    True
# 29674   Andy Wilkinson   awilkinson@pivotal.io  2017-03-24T11:26:27Z    True
# 29742  Stephane Nicoll      snicoll@pivotal.io  2017-03-02T17:31:53Z    True
# 29756     Brian Clozel      bclozel@pivotal.io  2017-02-24T12:03:11Z    True
# 29846     Phillip Webb        pwebb@pivotal.io  2017-01-06T04:04:48Z    True
#
# [772 rows x 13 columns]

# %%
df[df['label'] == 3]
# Out:
#        repo_id  label                                                url  \
# id
# 38           1      3  https://github.com/junit-team/junit4/commit/6c...
# 97           1      3  https://github.com/junit-team/junit4/commit/e2...
# 112          1      3  https://github.com/junit-team/junit4/commit/3b...
# 131          1      3  https://github.com/junit-team/junit4/commit/78...
# 171          1      3  https://github.com/junit-team/junit4/commit/8e...
# ...        ...    ...                                                ...
# 25494        5      3  https://github.com/spring-projects/spring-boot...
# 25719        5      3  https://github.com/spring-projects/spring-boot...
# 27076        5      3  https://github.com/spring-projects/spring-boot...
# 27983        5      3  https://github.com/spring-projects/spring-boot...
# 28495        5      3  https://github.com/spring-projects/spring-boot...
#
#        if_mulit_commit                                            message  \
# id
# 38                 NaN          Remove reference to obsolete mailing list
# 97                 NaN   Change links to point directly to junit4/5 repos
# 112                NaN               Use new logo and link to new website
# 131                NaN  Publish from Travis <enter>  <enter> Remove 11...
# 171                NaN                                          Add siili
# ...                ...                                                ...
# 25494              NaN                 Make fields private where possible
# 25719              NaN                           Reduce logging in Travis
# 27076              NaN  Add SpringApplicationErrorHandler <enter>  <en...
# 27983              NaN  Polish spring-boot-loader-tools <enter>  <ente...
# 28495              NaN      Improve Spring Session MongoDB support naming
#
#                                             new_message1    authorName  \
# id
# 38            Remove reference to obsolete mailing list   Marc Philipp
# 97     Change links to point directly to junit4/5 repos   Marc Philipp
# 112                Use new logo and link to new website   Marc Philipp
# 131    Publish from Travis  <enter> Remove 11 <enter>...  Marc Philipp
# 171                                   Add  <file_name>    Marc Philipp
# ...                                                  ...           ...
# 25494                Make fields private where possible   Phillip Webb
# 25719                          Reduce logging in Travis   Phillip Webb
# 27076  Add  <file_name> <enter> [#48055575] [bs-31] A...     Dave Syer
# 27983  Polish spring-boot-loader-tools  <enter> Issue...  Phillip Webb
# 28495                     Improve <iden> support naming   Vedran Pavic
#
#                   authorEmail            commitDate   committerName  \
# id
# 38        mail@marcphilipp.de  2019-11-02T13:05:11Z    Marc Philipp
# 97        mail@marcphilipp.de  2018-11-25T18:48:18Z    Marc Philipp
# 112       mail@marcphilipp.de  2016-04-18T19:15:59Z    Marc Philipp
# 131       mail@marcphilipp.de  2018-09-30T18:47:01Z    Marc Philipp
# 171       mail@marcphilipp.de  2015-10-07T17:32:12Z    Marc Philipp
# ...                       ...                   ...             ...
# 25494     pwebb@gopivotal.com  2014-01-22T00:21:00Z    Phillip Webb
# 25719     pwebb@gopivotal.com  2014-01-16T21:37:19Z    Phillip Webb
# 27076     dsyer@gopivotal.com  2013-11-04T16:00:48Z       Dave Syer
# 27983        pwebb@vmware.com  2013-07-30T07:04:20Z    Phillip Webb
# 28495  vedran.pavic@gmail.com  2017-06-28T12:40:38Z  Andy Wilkinson
#
#               committerEmail         committerDate is_good
# id
# 38       mail@marcphilipp.de  2019-11-02T13:05:11Z    True
# 97       mail@marcphilipp.de  2018-11-25T18:48:18Z    True
# 112      mail@marcphilipp.de  2016-04-18T19:15:59Z   False
# 131      mail@marcphilipp.de  2018-09-30T19:29:05Z   False
# 171      mail@marcphilipp.de  2015-10-07T17:32:12Z   False
# ...                      ...                   ...     ...
# 25494    pwebb@gopivotal.com  2014-01-22T00:29:07Z   False
# 25719    pwebb@gopivotal.com  2014-01-16T21:37:19Z   False
# 27076    dsyer@gopivotal.com  2013-11-04T17:07:04Z    True
# 27983       pwebb@vmware.com  2013-07-30T07:06:35Z   False
# 28495  awilkinson@pivotal.io  2017-09-25T09:51:45Z   False
#
# [428 rows x 13 columns]

# %%
# calculate the precision and recall

true_positives = df[(df['is_good'] == True) & (df['label'] == 3)].shape[0]
false_positives = df[(df['is_good'] == True) & (df['label'] != 3)].shape[0]
false_negatives = df[(df['is_good'] == False) & (df['label'] == 3)].shape[0]

precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)

precision, recall
# Out:
# (0.23575129533678757, 0.4252336448598131)
